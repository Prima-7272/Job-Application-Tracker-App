# %%
# 1. Import Libraries
# 2. Load Dataset
# 3. Exploratory Data Analysis (EDA)
# 4. Data Cleaning & Preprocessing
# 5. Feature Engineering
# 6. User Profile Creation
# 7. Rule-based Matching
# 8. NLP Matching
# 9. Weighted Scoring
# 10. Final Recommendation System

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("../data/job_posts_93.csv")

df.head()
# Out:
#                company_name                    job_title  role_category  \
# 0     Digital AI Studio ApS  Junior Data Engineer Intern  Data Engineer
# 1      Nordic AI Studio ApS                        ML/AI          ML/AI
# 2      Odense DataWorks ApS         Senior Data Engineer  Data Engineer
# 3          Cloud Design ApS              Product Analyst   Data Analyst
# 4  Copenhagen Solutions ApS               UX/UI Designer             UX
#
#   company_sector        city            region  \
# 0     Technology      Odense  Southern Denmark
# 1     Technology  Copenhagen    Capital Region
# 2     Technology      Odense  Southern Denmark
# 3     Technology     Aalborg     North Denmark
# 4     Consulting  Copenhagen    Capital Region
#
#                            technical_skills_required employment_type  \
# 0  SQL Basics, Excel, Git, Python Basics, Data Cl...      Internship
# 1  Python, Scikit-learn, Model Deployment, ML Pip...       Full-time
# 2  Apache Spark, Kafka, Python, SQL, Data Archite...       Full-time
# 3  SQL, Excel, Power BI, Product Analytics, Data ...       Full-time
# 4  Figma, Adobe XD, Wireframing, Prototyping, Use...       Full-time
#
#   work_mode  experience_required_years education_required  \
# 0    Hybrid                          0  Bachelor's Degree
# 1    Hybrid                          2    Master's Degree
# 2   On-site                          6    Master's Degree
# 3   On-site                          4  Bachelor's Degree
# 4    Hybrid                          2    Master's Degree
#
#   English_required_level Danish_required_level  salary_min_dkk_monthly  \
# 0           Intermediate                 Basic                   40000
# 1               Advanced   Danish not required                   55000
# 2                 Fluent                 Basic                   62000
# 3               Advanced                 Basic                   55000
# 4               Advanced          Intermediate                   48000
#
#    salary_max_dkk_monthly experience_level  \
# 0                   50000      Entry Level
# 1                   65000        Mid Level
# 2                   72000     Senior Level
# 3                   65000     Senior Level
# 4                   58000        Mid Level
#
#                                 soft_skills_required
# 0  Problem Solving, Collaboration, Attention to D...
# 1  Critical Thinking, Research Mindset, Problem S...
# 2  Leadership, Ownership, Stakeholder Communicati...
# 3  Communication, Analytical Thinking, Problem So...
# 4  Creativity, Communication, Empathy, Collaborat...

# %% [markdown]
# #  Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (93, 17)

# %%
df.columns
# Out:
# Index(['company_name', 'job_title', 'role_category', 'company_sector', 'city',
#        'region', 'technical_skills_required', 'employment_type', 'work_mode',
#        'experience_required_years', 'education_required',
#        'English_required_level', 'Danish_required_level',
#        'salary_min_dkk_monthly', 'salary_max_dkk_monthly', 'experience_level',
#        'soft_skills_required'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   company_name               93 non-null     object
#  1   job_title                  93 non-null     object
#  2   role_category              93 non-null     object
#  3   company_sector             93 non-null     object
#  4   city                       93 non-null     object
#  5   region                     93 non-null     object
#  6   technical_skills_required  93 non-null     object
#  7   employment_type            93 non-null     object
#  8   work_mode                  93 non-null     object
#  9   experience_required_years  93 non-null     int64
#  10  education_required         93 non-null     object
#  11  English_required_level     93 non-null     object
#  12  Danish_required_level      93 non-null     object
#  13  salary_min_dkk_monthly     93 non-null     int64
#  14  salary_max_dkk_monthly     93 non-null     int64
#  15  experience_level           93 non-null     object
#  16  soft_skills_required       93 non-null     object
# dtypes: int64(3), object(14)
# memory usage: 12.5+ KB

# %%
df.isna().sum()
# Out:
# company_name                 0
# job_title                    0
# role_category                0
# company_sector               0
# city                         0
# region                       0
# technical_skills_required    0
# employment_type              0
# work_mode                    0
# experience_required_years    0
# education_required           0
# English_required_level       0
# Danish_required_level        0
# salary_min_dkk_monthly       0
# salary_max_dkk_monthly       0
# experience_level             0
# soft_skills_required         0
# dtype: int64

# %%
df["role_category"].value_counts()
# Out:
# role_category
# DevOps           22
# Data Analyst     22
# BI               20
# ML/AI            12
# Data Engineer    11
# UX                6
# Name: count, dtype: int64

# %%
role_counts = df[
    "role_category"
].value_counts()

fig, ax = plt.subplots(figsize=(8,5))

bars = ax.bar(
    role_counts.index,
    role_counts.values
)

# Add values on top of bars
ax.bar_label(
    bars,
    padding=3
)

ax.set_title("Role Category Distribution")
ax.set_xlabel("Role Category")
ax.set_ylabel("Count")

plt.xticks(rotation=0)

plt.tight_layout()

plt.show()

# %%
# Group rare sectors
sector_counts = df["company_sector"].value_counts()

rare_sectors = sector_counts[
    sector_counts < 3
].index

df["company_sector"] = df[
    "company_sector"
].replace(
    rare_sectors,
    "Other"
)

# Recalculate counts
sector_counts = df[
    "company_sector"
].value_counts()

# Create plot
fig, ax = plt.subplots(figsize=(8, 5))

bars = ax.bar(
    sector_counts.index,
    sector_counts.values
)

# Add numbers on bars
ax.bar_label(
    bars,
    padding=3
)

ax.set_title("Company Sector Distribution")
ax.set_xlabel("Company Sector")
ax.set_ylabel("Number of Job Posts")

plt.xticks(rotation=45, ha="right")

plt.tight_layout()

plt.show()

# %%
df["city"].value_counts()
# Out:
# city
# Copenhagen    47
# Aarhus        19
# Odense        15
# Aalborg        5
# Esbjerg        3
# Vejle          1
# Randers        1
# Herlev         1
# Ballerup       1
# Name: count, dtype: int64

# %%
city_counts = df["city"].value_counts()

fig, ax = plt.subplots(figsize=(8, 5))

bars = ax.bar(
    city_counts.index,
    city_counts.values
)

# Add values on top of bars
ax.bar_label(
    bars,
    padding=3
)

ax.set_title("Job Distribution by City")
ax.set_xlabel("City")
ax.set_ylabel("Number of Job Posts")

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()

# %%
df["employment_type"].value_counts()
# Out:
# employment_type
# Full-time     73
# Part-time     14
# Internship     6
# Name: count, dtype: int64

# %%
employment_counts = df[
    "employment_type"
].value_counts()

fig, ax = plt.subplots(figsize=(7,5))

bars = ax.bar(
    employment_counts.index,
    employment_counts.values
)

# Add labels on bars
ax.bar_label(
    bars,
    padding=3
)

ax.set_title("Employment Type Distribution")
ax.set_xlabel("Employment Type")
ax.set_ylabel("Number of Job Posts")

plt.tight_layout()

plt.show()

# %%
df["work_mode"].value_counts()
# Out:
# work_mode
# Hybrid     58
# Remote     18
# On-site    17
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))

df["work_mode"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.title("Work Mode Share")
plt.ylabel("")

plt.tight_layout()

plt.show()

# %%
df["education_required"].value_counts()
# Out:
# education_required
# Bachelor's Degree    70
# Master's Degree      22
# PhD                   1
# Name: count, dtype: int64

# %%
education_counts = df[
    "education_required"
].value_counts()

fig, ax = plt.subplots(figsize=(8,5))

bars = ax.bar(
    education_counts.index,
    education_counts.values
)

# Add labels
ax.bar_label(
    bars,
    padding=3
)

ax.set_title("Education Requirement Distribution")
ax.set_xlabel("Education Level")
ax.set_ylabel("Number of Job Posts")

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()

# %%
df["experience_required_years"].describe()
# Out:
# count    93.000000
# mean      2.666667
# std       1.562699
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       6.000000
# Name: experience_required_years, dtype: float64

# %%
df["experience_level"] = pd.cut(
    df["experience_required_years"],
    bins=[-1, 1, 3, 6],
    labels=[
        "Entry Level",
        "Mid Level",
        "Senior Level"
    ]
)
df["experience_level"].value_counts()
# Out:
# experience_level
# Mid Level       40
# Senior Level    30
# Entry Level     23
# Name: count, dtype: int64

# %%
experience_order = [
    "Entry Level",
    "Mid Level",
    "Senior Level"
]

experience_counts = df[
    "experience_level"
].value_counts().reindex(
    experience_order
)

fig, ax = plt.subplots(figsize=(7,5))

bars = ax.bar(
    experience_counts.index,
    experience_counts.values
)

ax.bar_label(
    bars,
    padding=3
)

ax.set_title("Experience Level Distribution")
ax.set_xlabel("Experience Level")
ax.set_ylabel("Number of Job Posts")

plt.tight_layout()

plt.show()

# %%
df["English_required_level"].value_counts()
# Out:
# English_required_level
# Advanced        52
# Intermediate    29
# Fluent          12
# Name: count, dtype: int64

# %%
df["Danish_required_level"].value_counts()
# Out:
# Danish_required_level
# Danish not required    34
# Basic                  31
# Intermediate           28
# Name: count, dtype: int64

# %%
# Count values
english_counts = df[
    "English_required_level"
].value_counts()

danish_counts = df[
    "Danish_required_level"
].value_counts()

# Create figure with 2 subplots
fig, axes = plt.subplots(
    1, 2,
    figsize=(14,6)
)

# English pie chart
axes[0].pie(
    english_counts.values,
    labels=english_counts.index,
    autopct="%1.1f%%"
)

axes[0].set_title(
    "English Requirement Distribution"
)

# Danish pie chart
axes[1].pie(
    danish_counts.values,
    labels=danish_counts.index,
    autopct="%1.1f%%"
)

axes[1].set_title(
    "Danish Requirement Distribution"
)

plt.tight_layout()

plt.show()

# %%
df[
    [
        "salary_min_dkk_monthly",
        "salary_max_dkk_monthly"
    ]
].describe()
# Out:
#        salary_min_dkk_monthly  salary_max_dkk_monthly
# count               93.000000               93.000000
# mean             50741.935484            60806.451613
# std               9148.417808             9150.027399
# min              35000.000000            45000.000000
# 25%              45000.000000            55000.000000
# 50%              55000.000000            65000.000000
# 75%              55000.000000            65000.000000
# max              65000.000000            75000.000000

# %%
salary_summary = df.groupby(
    ["role_category", "experience_level"]
)["salary_max_dkk_monthly"].mean().unstack()

salary_summary.plot(
    kind="bar",
    figsize=(10,6)
)

plt.title("Average Salary by Role and Experience Level")
plt.xlabel("Role Category")
plt.ylabel("Average Maximum Salary (DKK)")

plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Cleaning & Preprocessing

# %% [markdown]
# ## Data Cleaning
# - Handle missing values
# - Remove duplicate rows
# - Fix inconsistent values

# %%
# Handle missing values

df.isnull().sum()
# Out:
# company_name                 0
# job_title                    0
# role_category                0
# company_sector               0
# city                         0
# region                       0
# technical_skills_required    0
# employment_type              0
# work_mode                    0
# experience_required_years    0
# education_required           0
# English_required_level       0
# Danish_required_level        0
# salary_min_dkk_monthly       0
# salary_max_dkk_monthly       0
# experience_level             0
# soft_skills_required         0
# dtype: int64

# %%
# Remove duplicate rows

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["technical_skills_required"]
# Out:
# 0     SQL Basics, Excel, Git, Python Basics, Data Cl...
# 1     Python, Scikit-learn, Model Deployment, ML Pip...
# 2     Apache Spark, Kafka, Python, SQL, Data Archite...
# 3     SQL, Excel, Power BI, Product Analytics, Data ...
# 4     Figma, Adobe XD, Wireframing, Prototyping, Use...
# 5     Excel, SQL Basics, Power BI, Data Cleaning, Go...
# 6     Power BI, Excel, A/B Testing, SQL, Data Visual...
# 7     SQL, Excel, Power BI, Data Visualization, Repo...
# 8     Python, TensorFlow, PyTorch, Scikit-learn, SQL...
# 9     Power BI, SQL, Reporting, Data Analysis, Busin...
# 10    Power BI, Data Cleaning, Data Visualization, B...
# 11    Python, TensorFlow, PyTorch, NLP, Computer Vis...
# 12    Figma, Adobe XD, Wireframing, Prototyping, Use...
# 13    Python, TensorFlow, Computer Vision, Deep Lear...
# 14    SQL, Excel, Data Analysis, Data Visualization,...
# 15    Docker, AWS, SQL, Python, Apache Spark, Airflo...
# 16    SQL, Excel, Advanced Excel, Data Analysis, Dat...
# 17    SQL, Excel, Data Cleaning, Data Visualization,...
# 18    SQL, Excel, Advanced Excel, Power BI, Reportin...
# 19    SQL, Excel, Advanced Excel, Data Cleaning, Dat...
# 20    Figma, Adobe XD, Wireframing, Prototyping, Use...
# 21    SQL, Excel, Data Cleaning, Data Visualization,...
# 22    SQL, Excel, Data Analysis, Data Visualization,...
# 23    SQL, Python Basics, Linux, Git, Data Cleaning,...
# 24    Figma, Adobe XD, Wireframing, Prototyping, Use...
# 25    Python, SQL, Apache Spark, Airflow, AWS, Docke...
# 26    SQL, Excel, Data Cleaning, Data Analysis, Data...
# 27    Python, TensorFlow, Basic Deep Learning, Data ...
# 28    SQL, Advanced Excel, Power BI, Tableau, Report...
# 29    SQL, Python, Apache Spark, Airflow, AWS, Docke...
# 30    Python, SQL, Scikit-learn, TensorFlow, PyTorch...
# 31    Python, TensorFlow, PyTorch, Deep Learning, NL...
# 32    Python, TensorFlow, PyTorch, Deep Learning, NL...
# 33    Excel, SQL Basics, Git, Python Basics, Data Cl...
# 34    SQL, Tableau, Reporting, Dashboard Development...
# 35    Figma, Adobe XD, Wireframing, Prototyping, Use...
# 36    Docker, SQL, Kubernetes, AWS, Python, Airflow,...
# 37    SQL, Excel, Data Cleaning, Data Visualization,...
# 38    SQL, Advanced Excel, Power BI, Tableau, Report...
# 39    Python, TensorFlow, PyTorch, SQL, Scikit-learn...
# 40    SQL, Excel, Data Cleaning, Data Visualization,...
# 41    Python, Scikit-learn, Machine Learning, Model ...
# 42    SQL Basics, Python Basics, Git, Excel, Data Cl...
# 43    Python Basics, SQL Basics, Git, Data Cleaning,...
# 44    SQL, Power BI, Tableau, Excel, Python, Statist...
# 45    SQL, Excel, Power BI, Tableau, Reporting, Dash...
# 46    Figma, Adobe XD, Wireframing, Prototyping, Use...
# 47    Python, Scikit-learn, Machine Learning, Model ...
# 48    SQL, Excel, Power BI, Tableau, Reporting, Dash...
# 49    Linux, Docker, Git, CI/CD Basics, Bash Scripti...
# 50    AWS, Terraform, Linux, Docker, Kubernetes, Clo...
# 51    Kubernetes, Terraform, AWS, Platform Architect...
# 52    Docker, Kubernetes, Linux, CI/CD, Terraform, J...
# 53    Kubernetes, Docker, CI/CD Pipelines, Linux, Te...
# 54    Docker, Kubernetes, AWS, CI/CD Pipelines, Linu...
# 55    Docker, Kubernetes, PostgreSQL, CI/CD Pipeline...
# 56    Docker, Kubernetes, Linux, Terraform, CI/CD Pi...
# 57    Linux, Docker, Git, Bash Scripting, CI/CD Basi...
# 58    Kubernetes, Docker, Linux, Terraform, CI/CD Pi...
# 59    AWS, Kubernetes, Terraform, Docker, CI/CD Pipe...
# 60    AWS, Azure, Terraform, Kubernetes, Docker, Clo...
# 61    AWS, Kubernetes, Platform Architecture, Terraf...
# 62    Kubernetes, Platform Architecture, Terraform, ...
# 63    Docker, Kubernetes, Linux, Terraform, CI/CD Pi...
# 64    Kubernetes, Containerization, Platform Enginee...
# 65    Kubernetes, Terraform, AWS, CI/CD Architecture...
# 66    AWS, Azure, Cloud Infrastructure, Linux, Terra...
# 67    Docker, Kubernetes, Terraform, Linux, CI/CD Pi...
# 68    Linux, Git, Python Basics, Docker Basics, Bash...
# 69    Power BI, Data Modeling, SQL, DAX, Data Wareho...
# 70    Power BI, Excel, SQL, Data Visualization, Dash...
# 71    Power BI, DAX, SQL, Data Modeling, Dashboard D...
# 72    Power BI, SQL, Data Modeling, Dashboard Develo...
# 73    Power BI, SQL, Data Visualization, Excel, Dash...
# 74    Power BI, SQL, Excel, Data Visualization, Dash...
# 75    Power BI, Excel, SQL, Data Visualization, Dash...
# 76    Power BI, DAX, SQL, Data Modeling, Dashboard D...
# 77    Power BI, Excel, SQL, Financial Reporting, Pow...
# 78    Excel, SQL, Power BI, Pricing Analysis, Revenu...
# 79    Power BI, Excel, SQL, Data Visualization, Dash...
# 80    Power BI, SQL, Excel, Data Visualization, Busi...
# 81    Excel, SQL, Power BI, Data Visualization, Goog...
# 82    SQL, ETL Pipelines, Data Warehousing, Power BI...
# 83    SQL, Power BI, Excel, Data Visualization, Busi...
# 84    Power BI, SQL, Data Modeling, ETL Processes, D...
# 85    Python, SQL, Apache Spark, ETL Pipelines, Post...
# 86    Power BI, SQL, Data Modeling, DAX, Dashboard D...
# 87    Power BI, DAX, SQL, Data Modeling, Dashboard D...
# 88    Docker, Kubernetes, CI/CD, Linux, Git, Jenkins...
# 89    AWS, Kubernetes, Docker, Terraform, CI/CD, Lin...
# 90    Python, Scikit-learn, TensorFlow, SQL, Pandas,...
# 91    SQL, Power BI, Python, Data Visualization, Exc...
# 92    Excel, SQL, Power BI, Data Cleaning, Python, P...
# Name: technical_skills_required, dtype: object

# %% [markdown]
# # Text Normalization
# - Convert text to lowercase
# - Remove extra spaces
# - Normalize skill names
# - Remove punctuation

# %%
# Text Normalization
tech_all_skills = (
    df["technical_skills_required"]
    .str.lower()
    .str.split(",")
    .explode()
    .str.strip()
)

pd.set_option(
    "display.max_rows",
    None
)

tech_all_skills.value_counts().head(20)
# Out:
# technical_skills_required
# sql                       59
# excel                     43
# power bi                  41
# data visualization        39
# python                    37
# docker                    34
# linux                     29
# dashboard development     28
# git                       27
# data analysis             26
# terraform                 24
# aws                       23
# kubernetes                23
# data cleaning             23
# business intelligence     23
# data modeling             21
# bash scripting            18
# tableau                   18
# kpi analysis              17
# infrastructure as code    17
# Name: count, dtype: int64

# %%
tech_skill_counts = (
    tech_all_skills
    .value_counts()
    .reset_index()
)

tech_skill_counts.columns = [
    "skill",
    "count"
]

tech_skill_counts.head(10)
# Out:
#                    skill  count
# 0                    sql     59
# 1                  excel     43
# 2               power bi     41
# 3     data visualization     39
# 4                 python     37
# 5                 docker     34
# 6                  linux     29
# 7  dashboard development     28
# 8                    git     27
# 9          data analysis     26

# %%
tech_skill_counts[["skill"]].to_csv(
    "../data/technical_skills.csv",
    index=False
)

# %%
tech_skills_by_role = (
    df.groupby("role_category")["technical_skills_required"]
    .apply(lambda x:
        x.str.lower()
         .str.split(",")
         .explode()
         .str.strip()
         .value_counts()
    )
)

tech_skills_by_role
# Out:
# role_category
# BI             sql                              20
#                power bi                         19
#                excel                            18
#                data visualization               17
#                business intelligence            15
#                dashboard development            13
#                data modeling                    12
#                dax                              10
#                tableau                           6
#                power query                       6
#                etl processes                     6
#                reporting solutions               5
#                data cleaning                     5
#                reporting tools                   5
#                python                            5
#                data analysis                     4
#                dashboard reporting               4
#                google sheets                     4
#                azure data factory                4
#                kpi analysis                      4
#                kpi reporting                     4
#                performance optimization          3
#                basic dax                         3
#                kpi tracking                      3
#                data warehousing                  2
#                reporting                         2
#                commercial reporting              2
#                forecasting                       2
#                ssis                              2
#                inventory analysis                1
#                supply chain analysis             1
#                logistics kpis                    1
#                dashboard strategy                1
#                azure synapse                     1
#                etl architecture                  1
#                reporting automation              1
#                financial reporting               1
#                automation tools                  1
#                enterprise analytics              1
#                cloud bi platforms                1
#                pricing analysis                  1
#                process automation                1
#                revenue management                1
#                financial modeling                1
#                basic statistics                  1
#                survey analysis                   1
#                presentation tools                1
#                etl pipelines                     1
#                postgresql                        1
#                apache spark                      1
#                data integration                  1
#                dashboard optimization            1
#                business analysis                 1
#                statistical analysis              1
#                ssrs                              1
#                database management               1
# Data Analyst   power bi                         22
#                data visualization               22
#                sql                              21
#                excel                            20
#                dashboard development            15
#                data analysis                    15
#                python                           14
#                kpi analysis                     13
#                data cleaning                    13
#                tableau                          12
#                reporting                        10
#                business intelligence             8
#                kpi reporting                     7
#                advanced excel                    5
#                a/b testing                       4
#                data modeling                     4
#                basic python                      4
#                statistics                        4
#                google sheets                     3
#                data interpretation               3
#                experimentation                   3
#                customer insights                 3
#                product analytics                 3
#                business reporting                2
#                risk assessment                   2
#                pos systems                       2
#                financial analysis                2
#                pivot tables                      2
#                forecasting                       2
#                sales analysis                    2
#                business performance analysis     2
#                regulatory reporting              2
#                dashboards                        2
#                performance analysis              2
#                financial modeling                2
#                pandas                            2
#                analytics support                 2
#                user behavior analysis            2
#                reporting automation              2
#                dax                               1
#                google analytics                  1
#                business understanding            1
#                energy systems analysis           1
#                sustainability analysis           1
#                communication                     1
#                data storytelling                 1
#                sql basics                        1
#                basic reporting                   1
#                reporting tools                   1
#                learning ability                  1
#                mobility analytics                1
#                customer journey analysis         1
#                demand planning                   1
#                basic data analysis               1
#                finance analytics                 1
#                retail analytics                  1
#                system optimization               1
#                demand forecasting                1
#                energy data analysis              1
#                sustainability analytics          1
#                business analysis                 1
#                statistical analysis              1
#                etl basics                        1
#                basic statistics                  1
# Data Engineer  git                              10
#                sql                               7
#                linux                             7
#                python                            6
#                docker                            6
#                airflow                           6
#                apache spark                      6
#                data warehousing                  6
#                data pipeline basics              5
#                data cleaning                     5
#                docker basics                     5
#                cloud basics                      5
#                bash scripting                    5
#                excel                             5
#                python basics                     5
#                etl pipelines                     5
#                terraform                         5
#                ci/cd pipelines                   5
#                kubernetes                        5
#                aws                               5
#                linux basics                      4
#                sql basics                        4
#                kafka                             1
#                data architecture                 1
#                azure                             1
#                distributed systems               1
#                etl pipeline design               1
#                postgresql                        1
#                apache kafka                      1
#                cloud platforms                   1
#                data modeling                     1
# DevOps         linux                            22
#                docker                           21
#                terraform                        19
#                kubernetes                       18
#                aws                              18
#                infrastructure as code           17
#                jenkins                          14
#                bash scripting                   13
#                git                              13
#                ci/cd pipelines                  11
#                monitoring tools                  9
#                azure                             8
#                monitoring & logging              7
#                ansible                           7
#                cloud security                    6
#                distributed systems               5
#                gitops                            5
#                cloud networking                  5
#                monitoring & observability        5
#                automation frameworks             4
#                ci/cd                             4
#                ci/cd architecture                4
#                networking fundamentals           3
#                platform architecture             3
#                scripting                         3
#                ci/cd basics                      3
#                kubernetes basics                 2
#                aws basics                        2
#                containerization                  2
#                cloud infrastructure              2
#                postgresql                        1
#                automation scripts                1
#                backup & recovery                 1
#                platform engineering              1
#                database monitoring               1
#                openshift                         1
#                helm                              1
#                service mesh                      1
#                it operations                     1
#                python basics                     1
#                docker basics                     1
#                cloud basics                      1
#                sql basics                        1
# ML/AI          python                           12
#                feature engineering              12
#                sql                              11
#                tensorflow                        9
#                model deployment                  8
#                ml pipelines                      7
#                scikit-learn                      7
#                docker                            7
#                pytorch                           7
#                data analysis                     7
#                data preprocessing                6
#                mlops                             5
#                git                               4
#                computer vision                   4
#                pandas                            4
#                data modeling                     4
#                data pipelines                    4
#                nlp                               3
#                machine learning algorithms       3
#                stakeholder management            3
#                model training                    3
#                deep learning                     3
#                etl                               2
#                distributed systems               2
#                customer insights                 2
#                machine learning                  2
#                demand forecasting                2
#                system design                     2
#                performance optimization          2
#                scalability                       2
#                technical leadership              2
#                business analysis                 1
#                reporting                         1
#                process optimization              1
#                service analytics                 1
#                basic deep learning               1
#                basic mlops                       1
#                ai solutions development          1
#                retail analytics                  1
#                supply chain analytics            1
#                ml algorithms                     1
# UX             figma                             6
#                adobe xd                          6
#                wireframing                       6
#                prototyping                       6
#                user research                     6
#                interaction design                6
#                usability testing                 6
#                design systems                    6
#                ux design                         5
#                ui design                         4
#                user flows                        4
#                information architecture          4
#                usability optimization            4
#                ai product design                 2
#                human-centered design             2
#                reporting                         1
#                business analysis                 1
#                digital product design            1
#                system design                     1
#                basic design principles           1
# Name: technical_skills_required, dtype: int64

# %%
soft_all_skills = (
    df["soft_skills_required"]
    .str.lower()
    .str.split(",")
    .explode()
    .str.strip()
)

soft_all_skills.value_counts().head(20)
# Out:
# soft_skills_required
# problem solving              93
# communication                89
# adaptability                 88
# critical thinking            78
# collaboration                77
# analytical thinking          74
# attention to detail          69
# ownership                    44
# business understanding       43
# curiosity                    40
# decision making              39
# teamwork                     37
# data storytelling            32
# stakeholder collaboration    31
# stakeholder communication    28
# responsibility               27
# presentation skills          26
# willingness to learn         25
# continuous learning          25
# reliability mindset          23
# Name: count, dtype: int64

# %%
soft_skill_counts = (
    soft_all_skills
    .value_counts()
    .reset_index()
)

soft_skill_counts.columns = [
    "skill",
    "count"
]

soft_skill_counts.head(10)
# Out:
#                     skill  count
# 0         problem solving     93
# 1           communication     89
# 2            adaptability     88
# 3       critical thinking     78
# 4           collaboration     77
# 5     analytical thinking     74
# 6     attention to detail     69
# 7               ownership     44
# 8  business understanding     43
# 9               curiosity     40

# %%
soft_skill_counts[["skill"]].to_csv(
    "../data/soft_skills.csv",
    index=False
)

# %%
soft_skills_by_role = (
    df.groupby("role_category")["soft_skills_required"]
    .apply(lambda x:
        x.str.lower()
         .str.split(",")
         .explode()
         .str.strip()
         .value_counts()
    )
)

soft_skills_by_role
# Out:
# role_category
# BI             problem solving              20
#                communication                20
#                analytical thinking          19
#                collaboration                19
#                data storytelling            19
#                adaptability                 19
#                attention to detail          17
#                critical thinking            17
#                business understanding       16
#                presentation skills          12
#                decision making              12
#                stakeholder communication     8
#                ownership                     8
#                stakeholder collaboration     8
#                curiosity                     5
#                teamwork                      4
#                willingness to learn          4
#                commercial mindset            2
#                leadership                    1
#                mentoring                     1
#                strategic thinking            1
#                cross-team collaboration      1
#                process improvement           1
# Data Analyst   problem solving              22
#                attention to detail          22
#                analytical thinking          20
#                communication                20
#                critical thinking            20
#                adaptability                 20
#                collaboration                16
#                curiosity                    16
#                teamwork                     14
#                business understanding       13
#                data storytelling            13
#                willingness to learn          9
#                stakeholder collaboration     8
#                presentation skills           8
#                decision making               8
#                responsibility                5
#                stakeholder communication     5
#                leadership                    2
#                mentoring                     2
#                ownership                     2
#                cross-team collaboration      2
#                strategic thinking            2
#                critical thinkin              1
#                time management               1
# Data Engineer  problem solving              11
#                communication                11
#                adaptability                 11
#                collaboration                10
#                attention to detail          10
#                analytical thinking          10
#                teamwork                      8
#                responsibility                7
#                critical thinking             6
#                ownership                     6
#                curiosity                     5
#                willingness to learn          5
#                continuous learning           5
#                reliability mindset           5
#                business understanding        3
#                stakeholder communication     3
#                stakeholder collaboration     3
#                persistence                   2
#                system design thinking        1
#                decision making               1
#                strategic thinking            1
#                cross-team collaboration      1
#                mentoring                     1
#                leadership                    1
#                team leadership               1
#                project management            1
# DevOps         problem solving              22
#                adaptability                 22
#                communication                22
#                critical thinking            18
#                ownership                    18
#                reliability mindset          18
#                collaboration                17
#                analytical thinking          16
#                decision making              15
#                responsibility               15
#                continuous learning          13
#                stakeholder collaboration    12
#                cross-team collaboration      6
#                stakeholder communication     5
#                project leadership            5
#                attention to detail           5
#                mentoring                     5
#                leadership                    5
#                system design thinking        5
#                strategic thinking            5
#                teamwork                      4
#                curiosity                     4
#                willingness to learn          4
#                self-management               1
#                time management               1
#                accountability                1
#                business understanding        1
#                presentation skills           1
# ML/AI          critical thinking            12
#                problem solving              12
#                adaptability                 10
#                communication                10
#                ownership                    10
#                business understanding       10
#                collaboration                 9
#                curiosity                     9
#                analytical thinking           9
#                attention to detail           9
#                research mindset              8
#                continuous learning           7
#                leadership                    3
#                strategic thinking            3
#                system design thinking        3
#                mentoring                     3
#                stakeholder communication     3
#                decision making               3
#                cross-team collaboration      3
#                project leadership            3
#                willingness to learn          2
#                teamwork                      2
#                research leadership           2
#                innovation mindset            2
#                persistence                   1
# UX             creativity                    6
#                communication                 6
#                empathy                       6
#                collaboration                 6
#                problem solving               6
#                user-centered thinking        6
#                attention to detail           6
#                adaptability                  6
#                visual thinking               6
#                critical thinking             5
#                presentation skills           5
#                teamwork                      5
#                stakeholder communication     4
#                stakeholder communicatio      1
#                curiosity                     1
#                willingness to learn          1
# Name: soft_skills_required, dtype: int64

# %%
df.to_csv(
    "../data/cleaned_jobs_dataset.csv",
    index=False
)

# %%
df_jobs = pd.read_csv("cleaned_jobs_dataset.csv")
tech_skills_by_role.to_csv("../data/tech_skills_by_role.csv")
soft_skills_by_role.to_csv("../data/soft_skills_by_role.csv")
